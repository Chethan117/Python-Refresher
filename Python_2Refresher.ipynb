# %%
[1, 2, 3] + [4, 5, 6]
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
[1,2,3] *3
# Out:
# [1, 2, 3, 1, 2, 3, 1, 2, 3]

# %%
[1,2,3] * [1,2,3]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-efb732392402> in <module>()
# ----> 1 [1,2,3] * [1,2,3]
#
# TypeError: can't multiply sequence by non-int of type 'list'

# %%
marks = [90, 100, 30, 85, 60]
print(marks)
# Out:
# [90, 100, 30, 85, 60]

# %%
for ele in marks:
  print(ele*2)
# Out:
# 180
# 200
# 60
# 170
# 120

# %%
a = [1,2,3]
print(a)
print(id(a))

b = a
print(b)
print(id(b))


c =[1,2,3]
print(c)
print(id(c))


d = list(a) # creating new object, same data different location
print(d)
print(id(d))


e = a[:]
print(e)
print(id(e))
# Out:
# [1, 2, 3]
# 139853741788288
# [1, 2, 3]
# 139853741788288
# [1, 2, 3]
# 139853608016464
# [1, 2, 3]
# 139853608473696
# [1, 2, 3]
# 139853607997840

# %%
arr = [a+" "+b for a in ['Hello','Good'] for b in ['Dear','Bye']]
print(arr)
type(arr)
# Out:
# ['Hello Dear', 'Hello Bye', 'Good Dear', 'Good Bye']
# list

# %%
a[0] = 100
print(a)
print(b)
print(c)
print(d)
print(e)
# Out:
# [100, 2, 3]
# [100, 2, 3]
# [1, 2, 3]
# [1, 2, 3]
# [1, 2, 3]
